# %% [markdown]
# # Matplotlib notebook removed
#
# The original Matplotlib.ipynb has been removed from the repository and replaced with this pointer file.
# A backup of the original notebook is available as `Matplotlib.ipynb.bak`.
#
# The tutorial has been split into 7 sections, each in its own folder at the repository root:
#
# 1. 1_Basic_Line_Plot/
# 2. 2_Markers_Line_Styles/
# 3. 3_Titles_Labels_Ticks/
# 4. 4_Multiple_Plots/
# 5. 5_Bar_Charts/
# 6. 6_Scatter_Plots/
# 7. 7_Tips_and_Further_Reading/
#
# See each folder's README.md and example.py for commented explanations and runnable examples.
